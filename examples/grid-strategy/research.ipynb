# %%
import os
import sys
from pathlib import Path
import shutil
import datetime
import math

import attrs
from liblaf import cherries
from loguru import logger
from tqdm import tqdm

# 替换此行
# sys.path.insert(0, os.path.abspath(os.path.join(os.path.dirname(__file__), "../../src")))

# 方法1：使用当前工作目录
notebook_dir = os.getcwd()  # 获取当前工作目录
src_path = os.path.abspath(os.path.join(notebook_dir, "../../src"))
sys.path.insert(0, src_path)


import qoc 
import qoc.api as api # pyright: ignore


db: str = qoc.data_dir("database").as_uri().replace("file://", "lmdb://")


online: bool = False
symbols: list[str] = ["BTCUSDT"]
# , "ETHUSDT", "LTCUSDT", "XRPUSDT", "ADAUSDT", "SOLUSDT", "BNBUSDT", "LINKUSDT",
#             "DOGEUSDT", "SHIBUSDT", "PEPEUSDT", "PENGUUSDT","BONKUSDT", "TRUMPUSDT", "SPXUSDT", "FLOKIUSDT", "WIFUSDT"]



# symbols: list[str] = ["BTCUSDT", "DOGEUSDT"]    
transaction_fee: float = 0.01  # 交易费用为0.1%
interval: str = "5m"
start_date: str = "2024-01-01"
end_date: str = "2025-08-31"
output_dir: str = "/Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw"


offline_db_path = Path("examples/grid-strategy/data/database/")
if offline_db_path.exists():
    # logger.info(f"删除现有数据库文件夹: {offline_db_path}")
    shutil.rmtree(offline_db_path)



from offline_fetch import fetch_for_offline
import arcticdb as adb
uri = "lmdb://examples/grid-strategy/data/database_offline/"

ac = adb.Arctic(uri)

qoc_library = ac.get_library('market', create_if_missing=True)

fetch_for_offline(symbols, interval, start_date, end_date, output_dir, qoc_library)
# Out:
# 20250920 12:50:01.540620 36593 W arcticdb | LMDB path at /Users/lizeyu/Desktop/Quant-on-Crypto/examples/grid-strategy/examples/grid-strategy/data/database_offline/ has already been opened in this process which is not supported by LMDB. You should only open a single Arctic instance over a given LMDB path. To continue safely, you should delete this Arctic instance and any others over the LMDB path in this process and then try again. Current process ID=[2420]
# 🚀 开始处理 BTCUSDT …
# 1704085200000000 1756612800000000
# 当前索引: Index([   1704067499999,    1704067799999,    1704068099999,    1704068399999,
#           1704068699999,    1704068999999,    1704069299999,    1704069599999,
#           1704069899999,    1704070199999,
#        ...
#        1754003699999999, 1754003999999999, 1754004299999999, 1754004599999999,
#        1754004899999999, 1754005199999999, 1754005499999999, 1754005799999999,
#        1754006099999999, 1754006399999999],
#       dtype='int64', name='Close Time', length=166464)
# 1704067499999 1754006399999999
# 数据库中的整体时间范围: 1970-01-20 12:21:07 到 2025-07-31 19:59:59
# 请求的时间范围: 2024-01-01 00:00:00 到 2025-08-31 00:00:00
# ⚠️ 数据库时间范围不完全覆盖请求的时间范围
# 读取数据时出错: year 57552 is out of range
# 📥 需要下载新数据来填补数据缺口
#   下载数据: 2024-01-01 到 2025-08-31
# 当前索引类型: <class 'pandas.core.indexes.base.Index'>
# 当前列: ['index', 'Open Time', 'Open', 'High', 'Low', 'Close', 'Volume', 'Quote Asset Volume', 'Number of Trades', 'Taker Buy Base Volume', 'Taker Buy Quote Volume', 'Ignore']
# 'Close Time'不在列中，可能已经是索引或不存在
# 现有数据条数: 166464 行
# BTCUSDT-5m-2024-01.zip: 100%|██████████| 465k/465k [00:00<00:00, 838kB/s]
# ✅ 下载完成: BTCUSDT-5m-2024-01.zip
# BTCUSDT-5m-2024-02.zip: 100%|██████████| 434k/434k [00:00<00:00, 751kB/s]
# ✅ 下载完成: BTCUSDT-5m-2024-02.zip
# BTCUSDT-5m-2024-03.zip: 100%|██████████| 474k/474k [00:00<00:00, 841kB/s]
# ✅ 下载完成: BTCUSDT-5m-2024-03.zip
# BTCUSDT-5m-2024-04.zip: 100%|██████████| 455k/455k [00:00<00:00, 820kB/s]
# ✅ 下载完成: BTCUSDT-5m-2024-04.zip
# BTCUSDT-5m-2024-05.zip: 100%|██████████| 463k/463k [00:00<00:00, 859kB/s]
# ✅ 下载完成: BTCUSDT-5m-2024-05.zip
# BTCUSDT-5m-2024-06.zip: 100%|██████████| 440k/440k [00:00<00:00, 917kB/s]
# ✅ 下载完成: BTCUSDT-5m-2024-06.zip
# BTCUSDT-5m-2024-07.zip: 100%|██████████| 461k/461k [00:00<00:00, 858kB/s]
# ✅ 下载完成: BTCUSDT-5m-2024-07.zip
# BTCUSDT-5m-2024-08.zip: 100%|██████████| 464k/464k [00:00<00:00, 2.03MB/s]
# ✅ 下载完成: BTCUSDT-5m-2024-08.zip
# BTCUSDT-5m-2024-09.zip: 100%|██████████| 442k/442k [00:00<00:00, 755kB/s]
# ✅ 下载完成: BTCUSDT-5m-2024-09.zip
# BTCUSDT-5m-2024-10.zip: 100%|██████████| 459k/459k [00:00<00:00, 835kB/s]
# ✅ 下载完成: BTCUSDT-5m-2024-10.zip
# BTCUSDT-5m-2024-11.zip: 100%|██████████| 459k/459k [00:00<00:00, 844kB/s]
# ✅ 下载完成: BTCUSDT-5m-2024-11.zip
# BTCUSDT-5m-2024-12.zip: 100%|██████████| 475k/475k [00:00<00:00, 3.16MB/s]
# ✅ 下载完成: BTCUSDT-5m-2024-12.zip
# BTCUSDT-5m-2025-01.zip: 100%|██████████| 478k/478k [00:00<00:00, 862kB/s]
# ✅ 下载完成: BTCUSDT-5m-2025-01.zip
# BTCUSDT-5m-2025-02.zip: 100%|██████████| 429k/429k [00:00<00:00, 772kB/s]
# ✅ 下载完成: BTCUSDT-5m-2025-02.zip
# BTCUSDT-5m-2025-03.zip: 100%|██████████| 476k/476k [00:00<00:00, 1.04MB/s]
# ✅ 下载完成: BTCUSDT-5m-2025-03.zip
# BTCUSDT-5m-2025-04.zip: 100%|██████████| 457k/457k [00:00<00:00, 785kB/s]
# ✅ 下载完成: BTCUSDT-5m-2025-04.zip
# BTCUSDT-5m-2025-05.zip: 100%|██████████| 473k/473k [00:00<00:00, 796kB/s]
# ✅ 下载完成: BTCUSDT-5m-2025-05.zip
# BTCUSDT-5m-2025-06.zip: 100%|██████████| 453k/453k [00:00<00:00, 677kB/s]
# ✅ 下载完成: BTCUSDT-5m-2025-06.zip
# BTCUSDT-5m-2025-07.zip: 100%|██████████| 466k/466k [00:00<00:00, 762kB/s]
# ✅ 下载完成: BTCUSDT-5m-2025-07.zip
# BTCUSDT-5m-2025-08.zip: 100%|██████████| 468k/468k [00:00<00:00, 1.78MB/s]
# ✅ 下载完成: BTCUSDT-5m-2025-08.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw/BTCUSDT-5m-2024-01.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw/BTCUSDT-5m-2024-02.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw/BTCUSDT-5m-2024-03.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw/BTCUSDT-5m-2024-04.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw/BTCUSDT-5m-2024-05.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw/BTCUSDT-5m-2024-06.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw/BTCUSDT-5m-2024-07.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw/BTCUSDT-5m-2024-08.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw/BTCUSDT-5m-2024-09.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw/BTCUSDT-5m-2024-10.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw/BTCUSDT-5m-2024-11.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw/BTCUSDT-5m-2024-12.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw/BTCUSDT-5m-2025-01.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw/BTCUSDT-5m-2025-02.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw/BTCUSDT-5m-2025-03.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw/BTCUSDT-5m-2025-04.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw/BTCUSDT-5m-2025-05.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw/BTCUSDT-5m-2025-06.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw/BTCUSDT-5m-2025-07.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw/BTCUSDT-5m-2025-08.zip
# 新下载数据条数: 175392 行
# 合并前总条数: 341856 行
# 合并后总条数: 175392 行
# 重复条数: 166464 行
# ✅ 数据已保存到 /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw/BTCUSDT_klines_5m.csv
# ✅ 数据已写入数据库 BTCUSDT_klines_5m
#
# 合并后数据预览:
#                index      Open Time      Open      High       Low     Close  \
# Close Time
# 1704067499999      0  1704067200000  42283.58  42397.23  42261.02  42397.23
# 1704067799999      1  1704067500000  42397.22  42432.74  42385.26  42409.96
# 1704068099999      2  1704067800000  42409.97  42488.09  42409.96  42488.00
# 1704068399999      3  1704068100000  42488.00  42554.57  42458.58  42458.85
# 1704068699999      4  1704068400000  42458.85  42491.10  42445.84  42473.93
#
#                   Volume  Quote Asset Volume  Number of Trades  \
# Close Time
# 1704067499999  155.25731        6.572926e+06              6350
# 1704067799999  141.31102        5.993375e+06              5134
# 1704068099999  135.14249        5.738386e+06              5167
# 1704068399999  163.32541        6.943230e+06              6153
# 1704068699999  117.27112        4.979136e+06              3094
#
#                Taker Buy Base Volume  Taker Buy Quote Volume  Ignore
# Close Time
# 1704067499999              106.05732            4.490262e+06       0
# 1704067799999               69.45156            2.945452e+06       0
# 1704068099999               73.25966            3.110338e+06       0
# 1704068399999               82.81591            3.520689e+06       0
# 1704068699999               49.06278            2.083183e+06       0

# %%
major_list = ["BTCUSDT", "ETHUSDT", "LTCUSDT", "XRPUSDT", "ADAUSDT", "SOLUSDT", "BNBUSDT", "LINKUSDT"]
meme_list = ["DOGEUSDT", "SHIBUSDT", "PEPEUSDT", "PENGUUSDT","BONKUSDT", "TRUMPUSDT", "SPXUSDT", "FLOKIUSDT", "WIFUSDT"]

# %%
# by million

volume_dict = {
    "BTCUSDT": 19.92, 
    "ETHUSDT": 120.7, 
    "XRPUSDT": 59.77*1000,
    "BNBUSDT": 139.18, 
    "SOLUSDT": 543.03, 
    "ADAUSDT": 35.79*1000,
    "LINKUSDT": 678.09, 
    "LTCUSDT": 76.31,

    "DOGEUSDT": 151*1000, 
    "SHIBUSDT": 589.24*1000000, 
    "PEPEUSDT": 420.68*1000000, 
    "PENGUUSDT": 62.86*1000,
    "BONKUSDT": 81.21*1000000, 
    # "TRUMPUSDT": 199.99, 
    "SPXUSDT": 930.99, 
    "FLOKIUSDT": 9.53*1000000, 
    "WIFUSDT": 998.83
    }

# %%
output_dir: str = "/Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw"
import pandas as pd

major_1st_mktval: pd.Series = None
major_rest_mktval: pd.Series = None
meme_1st_mktval: pd.Series = None
meme_rest_mktval: pd.Series = None

major_mktval_dict = {}
meme_mktval_dict = {}

from pathlib import Path
import pandas as pd
# 获取 output_dir 的路径
output_path = Path(output_dir)

# 遍历 output_dir 中的所有文件
for file in output_path.iterdir():
    if file.is_file():  # 检查是否是文件
        symbol = file.name.split('_')[0]
        df = pd.read_csv(file)
        df.set_index('Close Time', inplace=True)

        close_ts = df['Close']

        tot_volume = volume_dict.get(symbol, 0)

        tot_value = close_ts * tot_volume  # 总市值，单位：百万美元

        if symbol in major_list:
            if symbol == "BTCUSDT":
                major_1st_mktval = tot_value
            else:
                if major_rest_mktval is None:
                    major_rest_mktval = tot_value
                else:
                    major_rest_mktval += tot_value
            major_mktval_dict[symbol] = tot_value

        elif symbol in meme_list:
            if symbol == "DOGEUSDT":
                meme_1st_mktval = tot_value
            else:
                if meme_rest_mktval is None:
                    meme_rest_mktval = tot_value
                else:
                    meme_rest_mktval += tot_value
            meme_mktval_dict[symbol] = tot_value

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 7))
for symbol, mktval in major_mktval_dict.items():
    plt.plot(mktval.index, mktval, label=symbol, color='blue' if symbol == 'BTCUSDT' else 'green')
plt.plot(major_rest_mktval.index, major_rest_mktval, label="rest_major_marketcap", color='purple', linestyle='--')
plt.title("Major Assets Market Capitalization Over Time")
plt.xlabel("Time")
plt.ylabel("Market Capitalization (Million USD)")
plt.legend()
plt.grid()
plt.show()
plt.close()


plt.figure(figsize=(14, 7))
for symbol, mktval in meme_mktval_dict.items():
    plt.plot(mktval.index, mktval, label=symbol, color='orange' if symbol == 'DOGEUSDT' else 'red')
plt.plot(meme_rest_mktval.index, meme_rest_mktval, label="rest_meme_marketcap", color='purple', linestyle='--')
plt.title("MEME Assets Market Capitalization Over Time")
plt.xlabel("Time")
plt.ylabel("Market Capitalization (Million USD)")
plt.legend()
plt.grid()
plt.show()
plt.close()

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

def lead_lag_correlation(series1: pd.Series, series2: pd.Series, max_lag: int = 24, interval: int = 3): 
  """
  Measure the lead-lag correlation between two time series and visualize the effect of shifting timestamps.

  Parameters:
    series1 (pd.Series): The first time series.
    series2 (pd.Series): The second time series.
    max_lag (int): The maximum number of timestamps to shift forward and backward.

  Returns:
    pd.Series: A series containing the correlation values for each lag/lead.
  """
  correlations = {}

  for lag in range(-max_lag, max_lag + 1):
    if lag < 0:
      # series1 leads series2
      shifted_series2 = series2.shift(-lag*interval)
      corr = series1.corr(shifted_series2)
    elif lag > 0:
      # series2 leads series1
      shifted_series1 = series1.shift(lag*interval)
      corr = shifted_series1.corr(series2)
    else:
      # No lag
      corr = series1.corr(series2)
    
    correlations[lag] = corr

  # Convert to pandas Series for easier handling
  correlation_series = pd.Series(correlations)

  # Plot the results
  plt.figure(figsize=(10, 6))
  plt.plot(correlation_series.index, correlation_series.values, marker='o', linestyle='-')
  plt.axhline(0, color='gray', linestyle='--', linewidth=1)
  plt.title("Lead-Lag Correlation")
  plt.xlabel("Lag (timestamps)")
  plt.ylabel("Correlation")
  plt.grid()
  plt.show()

  return correlation_series

# %%
# 计算 major_1st_mktval 相隔12个时间戳的涨幅
major_1st_returns = major_1st_mktval.pct_change(periods=60)

# 计算 major_rest_mktval 相隔12个时间戳的涨幅
major_1st_returns = major_1st_mktval.pct_change(periods=60)

# 使用涨幅序列作为 lead_lag_correlation 的输入
lead_lag_correlation(major_1st_returns, major_1st_returns, max_lag=24, interval=30)
# Out:
# -24   -0.004834
# -23   -0.001488
# -22   -0.059143
# -21   -0.053683
# -20    0.023823
# -19    0.069984
# -18    0.066140
# -17    0.034416
# -16    0.005989
# -15   -0.047642
# -14   -0.023263
# -13    0.064935
# -12    0.061660
# -11    0.063776
# -10    0.110785
# -9     0.086682
# -8    -0.009660
# -7    -0.056267
# -6    -0.073346
# -5    -0.124867
# -4    -0.117238
# -3    -0.040548
# -2    -0.061528
# -1     0.436559
#  0     1.000000
#  1     0.436559
#  2    -0.061528
#  3    -0.040548
#  4    -0.117238
#  5    -0.124867
#  6    -0.073346
#  7    -0.056267
#  8    -0.009660
#  9     0.086682
#  10    0.110785
#  11    0.063776
#  12    0.061660
#  13    0.064935
#  14   -0.023263
#  15   -0.047642
#  16    0.005989
#  17    0.034416
#  18    0.066140
#  19    0.069984
#  20    0.023823
#  21   -0.053683
#  22   -0.059143
#  23   -0.001488
#  24   -0.004834
# dtype: float64

# %%
# 计算 major_1st_mktval 相隔12个时间戳的涨幅
major_1st_returns = major_1st_mktval.pct_change(periods=60)

# 计算 major_rest_mktval 相隔12个时间戳的涨幅
major_rest_returns = major_rest_mktval.pct_change(periods=60)

# 使用涨幅序列作为 lead_lag_correlation 的输入
lead_lag_correlation(major_1st_returns, major_rest_returns, max_lag=24, interval=30)
# Out:
# -24   -0.041126
# -23   -0.038633
# -22   -0.021208
# -21    0.026402
# -20    0.037907
# -19    0.016303
# -18    0.013232
# -17    0.010391
# -16    0.012637
# -15    0.022664
# -14    0.009912
# -13   -0.007247
# -12   -0.013713
# -11   -0.013278
# -10   -0.062223
# -9    -0.127684
# -8    -0.093894
# -7    -0.048732
# -6    -0.043533
# -5    -0.019653
# -4    -0.004722
# -3     0.006238
# -2     0.030401
# -1     0.451045
#  0     0.844725
#  1     0.425455
#  2     0.037292
#  3     0.033627
#  4     0.001264
#  5    -0.027939
#  6    -0.045505
#  7    -0.047341
#  8    -0.084364
#  9    -0.100784
#  10   -0.030999
#  11    0.016098
#  12    0.010273
#  13    0.020199
#  14    0.033678
#  15    0.033934
#  16    0.029177
#  17    0.033213
#  18    0.039381
#  19    0.030736
#  20    0.030476
#  21    0.034711
#  22    0.019608
#  23   -0.009372
#  24   -0.042668
# dtype: float64

# %%
# 计算 major_1st_mktval 相隔12个时间戳的涨幅
meme_1st_returns = meme_1st_mktval.pct_change(periods=60)

# 计算 major_rest_mktval 相隔12个时间戳的涨幅
meme_rest_returns = meme_rest_mktval.pct_change(periods=60)

# 使用涨幅序列作为 lead_lag_correlation 的输入
lead_lag_correlation(meme_1st_returns, meme_rest_returns, max_lag=24, interval=30)
# Out:
# -24   -0.030680
# -23   -0.020907
# -22   -0.012404
# -21    0.010282
# -20   -0.004084
# -19   -0.014359
# -18    0.018685
# -17    0.024132
# -16    0.011887
# -15    0.018595
# -14    0.029522
# -13    0.032208
# -12    0.026677
# -11    0.037667
# -10    0.015939
# -9    -0.051809
# -8    -0.060555
# -7    -0.031021
# -6    -0.026996
# -5    -0.023180
# -4    -0.004195
# -3     0.023155
# -2     0.032839
# -1     0.461428
#  0     0.894412
#  1     0.457277
#  2     0.020746
#  3     0.004305
#  4    -0.015467
#  5    -0.011828
#  6    -0.015297
#  7    -0.048723
#  8    -0.108584
#  9    -0.108835
#  10   -0.014762
#  11    0.046540
#  12    0.060117
#  13    0.067565
#  14    0.052483
#  15    0.026041
#  16    0.012216
#  17    0.019754
#  18    0.009109
#  19   -0.027343
#  20   -0.024954
#  21   -0.004238
#  22   -0.014425
#  23   -0.024106
#  24   -0.045921
# dtype: float64

# %%
_1st_major_to_meme_ratio = major_1st_mktval / meme_1st_mktval
rest_major_to_meme_ratio = major_rest_mktval / meme_rest_mktval

# %%
plt.figure(figsize=(14, 7))
plt.plot(_1st_major_to_meme_ratio.index, _1st_major_to_meme_ratio, label="1st_major_to_meme_ratio", color='blue')
plt.plot(rest_major_to_meme_ratio.index, rest_major_to_meme_ratio, label="rest_major_to_meme_ratio", color='orange')
plt.title("Major to MEME Market Capitalization Ratio Over Time")
plt.xlabel("Time")
plt.ylabel("Market Capitalization Ratio")
plt.legend()
plt.grid()
plt.show()
plt.close()

# %%
# 计算 major_1st_mktval 相隔12个时间戳的涨幅
_1st_m2m_returns = _1st_major_to_meme_ratio.pct_change(periods=96)

# 计算 major_rest_mktval 相隔12个时间戳的涨幅
rest_m2m_returns = rest_major_to_meme_ratio.pct_change(periods=96)

# 使用涨幅序列作为 lead_lag_correlation 的输入
lead_lag_correlation(_1st_m2m_returns, rest_m2m_returns, max_lag=24, interval=96)
# Out:
# -24    0.042485
# -23   -0.034455
# -22   -0.058636
# -21    0.037847
# -20    0.030271
# -19    0.026592
# -18   -0.022776
# -17    0.030524
# -16    0.055432
# -15    0.035969
# -14    0.022016
# -13    0.010491
# -12    0.060719
# -11   -0.025792
# -10    0.004102
# -9    -0.003688
# -8     0.007103
# -7    -0.009357
# -6    -0.013899
# -5     0.039765
# -4     0.021056
# -3     0.033936
# -2     0.018257
# -1     0.036609
#  0     0.527432
#  1    -0.050535
#  2    -0.046809
#  3    -0.026403
#  4     0.115936
#  5    -0.011590
#  6    -0.071938
#  7    -0.081328
#  8    -0.023810
#  9     0.050302
#  10   -0.078880
#  11   -0.000145
#  12    0.042298
#  13   -0.008898
#  14    0.017651
#  15    0.041451
#  16    0.000768
#  17   -0.058248
#  18   -0.015320
#  19   -0.013302
#  20    0.015667
#  21   -0.045593
#  22   -0.030133
#  23    0.070575
#  24   -0.025578
# dtype: float64
