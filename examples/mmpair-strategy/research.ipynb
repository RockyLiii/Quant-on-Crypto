# %%
import os
import sys
from pathlib import Path
import shutil
import datetime
import math

import attrs
from liblaf import cherries
from loguru import logger
from tqdm import tqdm

# 替换此行
# sys.path.insert(0, os.path.abspath(os.path.join(os.path.dirname(__file__), "../../src")))

# 方法1：使用当前工作目录
notebook_dir = os.getcwd()  # 获取当前工作目录
src_path = os.path.abspath(os.path.join(notebook_dir, "../../src"))
sys.path.insert(0, src_path)


import qoc 
import qoc.api as api # pyright: ignore


db: str = qoc.data_dir("database").as_uri().replace("file://", "lmdb://")


online: bool = False
symbols: list[str] = ["BTCUSDT", "XRPUSDT",  "DOGEUSDT", "PEPEUSDT"]
# , "ETHUSDT", "LTCUSDT", "ADAUSDT", "SOLUSDT", "BNBUSDT", "LINKUSDT",
#             "DOGEUSDT", "SHIBUSDT", "PEPEUSDT", "PENGUUSDT","BONKUSDT", "TRUMPUSDT", "SPXUSDT", "FLOKIUSDT", "WIFUSDT"]



# symbols: list[str] = ["BTCUSDT", "DOGEUSDT"]    
transaction_fee: float = 0.01  # 交易费用为0.1%
interval: str = "5m"
start_date: str = "2024-09-01"
end_date: str = "2025-08-31"
output_dir: str = "/Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp"


offline_db_path = Path("examples/grid-strategy/data/database_tp/")
if offline_db_path.exists():
    # logger.info(f"删除现有数据库文件夹: {offline_db_path}")
    shutil.rmtree(offline_db_path)



from offline_fetch import fetch_for_offline
import arcticdb as adb
uri = "lmdb://examples/grid-strategy/data/database_offline_tp/"

ac = adb.Arctic(uri)

qoc_library = ac.get_library('market', create_if_missing=True)

fetch_for_offline(symbols, interval, start_date, end_date, output_dir, qoc_library)
# Out:
# 20250923 21:44:29.617960 933995 W arcticdb | LMDB path at /Users/lizeyu/Desktop/Quant-on-Crypto/examples/mmpair-strategy/examples/grid-strategy/data/database_offline_tp/ has already been opened in this process which is not supported by LMDB. You should only open a single Arctic instance over a given LMDB path. To continue safely, you should delete this Arctic instance and any others over the LMDB path in this process and then try again. Current process ID=[18219]
# 🚀 开始处理 BTCUSDT …
# 1725163200000000 1756612800000000
# 数据库中没有 BTCUSDT_klines_5m 的数据
# 📥 需要下载新数据来填补数据缺口
#   下载数据: 2024-09-01 到 2025-08-31
# 数据库中没有 BTCUSDT_klines_5m 的数据
# BTCUSDT-5m-2024-09.zip: 100%|██████████| 442k/442k [00:00<00:00, 728kB/s]
# ✅ 下载完成: BTCUSDT-5m-2024-09.zip
# BTCUSDT-5m-2024-10.zip: 100%|██████████| 459k/459k [00:00<00:00, 1.50MB/s]
# ✅ 下载完成: BTCUSDT-5m-2024-10.zip
# BTCUSDT-5m-2024-11.zip: 100%|██████████| 459k/459k [00:00<00:00, 840kB/s]
# ✅ 下载完成: BTCUSDT-5m-2024-11.zip
# BTCUSDT-5m-2024-12.zip: 100%|██████████| 475k/475k [00:00<00:00, 3.67MB/s]
# ✅ 下载完成: BTCUSDT-5m-2024-12.zip
# BTCUSDT-5m-2025-01.zip: 100%|██████████| 478k/478k [00:00<00:00, 844kB/s]
# ✅ 下载完成: BTCUSDT-5m-2025-01.zip
# BTCUSDT-5m-2025-02.zip: 100%|██████████| 429k/429k [00:00<00:00, 718kB/s]
# ✅ 下载完成: BTCUSDT-5m-2025-02.zip
# BTCUSDT-5m-2025-03.zip: 100%|██████████| 476k/476k [00:00<00:00, 848kB/s]
# ✅ 下载完成: BTCUSDT-5m-2025-03.zip
# BTCUSDT-5m-2025-04.zip: 100%|██████████| 457k/457k [00:00<00:00, 808kB/s]
# ✅ 下载完成: BTCUSDT-5m-2025-04.zip
# BTCUSDT-5m-2025-05.zip: 100%|██████████| 473k/473k [00:00<00:00, 834kB/s]
# ✅ 下载完成: BTCUSDT-5m-2025-05.zip
# BTCUSDT-5m-2025-06.zip: 100%|██████████| 453k/453k [00:00<00:00, 745kB/s]
# ✅ 下载完成: BTCUSDT-5m-2025-06.zip
# BTCUSDT-5m-2025-07.zip: 100%|██████████| 466k/466k [00:00<00:00, 1.34MB/s]
# ✅ 下载完成: BTCUSDT-5m-2025-07.zip
# BTCUSDT-5m-2025-08.zip: 100%|██████████| 468k/468k [00:00<00:00, 475kB/s]
# ✅ 下载完成: BTCUSDT-5m-2025-08.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/BTCUSDT-5m-2024-09.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/BTCUSDT-5m-2024-10.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/BTCUSDT-5m-2024-11.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/BTCUSDT-5m-2024-12.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/BTCUSDT-5m-2025-01.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/BTCUSDT-5m-2025-02.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/BTCUSDT-5m-2025-03.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/BTCUSDT-5m-2025-04.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/BTCUSDT-5m-2025-05.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/BTCUSDT-5m-2025-06.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/BTCUSDT-5m-2025-07.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/BTCUSDT-5m-2025-08.zip
# 新下载数据条数: 105120 行
# 首次创建数据，总条数: 105120 行
# ✅ 数据已保存到 /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/BTCUSDT_klines_5m.csv
# ✅ 数据已写入数据库 BTCUSDT_klines_5m
#
# 合并后数据预览:
#                index      Open Time      Open      High       Low     Close  \
# Close Time
# 1725149099999      0  1725148800000  58974.00  58978.00  58957.01  58978.00
# 1725149399999      1  1725149100000  58978.00  59035.76  58975.41  59035.76
# 1725149699999      2  1725149400000  59035.75  59055.00  59023.00  59038.12
# 1725149999999      3  1725149700000  59038.11  59076.59  59024.00  59024.00
# 1725150299999      4  1725150000000  59024.00  59024.00  58991.10  58991.10
#
#                  Volume  Quote Asset Volume  Number of Trades  \
# Close Time
# 1725149099999  15.92811        9.392461e+05              2237
# 1725149399999  65.12076        3.841414e+06              2178
# 1725149699999  25.99014        1.534441e+06              2407
# 1725149999999  20.25307        1.195944e+06              2897
# 1725150299999  18.29866        1.079629e+06              1939
#
#                Taker Buy Base Volume  Taker Buy Quote Volume  Ignore
# Close Time
# 1725149099999                5.84918            3.449034e+05       0
# 1725149399999               59.49265            3.509428e+06       0
# 1725149699999                9.34836            5.518978e+05       0
# 1725149999999                8.85072            5.226532e+05       0
# 1725150299999               12.31213            7.263588e+05       0
#
# 🚀 开始处理 XRPUSDT …
# 1725163200000000 1756612800000000
# 数据库中没有 XRPUSDT_klines_5m 的数据
# 📥 需要下载新数据来填补数据缺口
#   下载数据: 2024-09-01 到 2025-08-31
# 数据库中没有 XRPUSDT_klines_5m 的数据
# XRPUSDT-5m-2024-09.zip: 100%|██████████| 345k/345k [00:00<00:00, 724kB/s]
# ✅ 下载完成: XRPUSDT-5m-2024-09.zip
# XRPUSDT-5m-2024-10.zip: 100%|██████████| 353k/353k [00:00<00:00, 724kB/s]
# ✅ 下载完成: XRPUSDT-5m-2024-10.zip
# XRPUSDT-5m-2024-11.zip: 100%|██████████| 375k/375k [00:00<00:00, 805kB/s]
# ✅ 下载完成: XRPUSDT-5m-2024-11.zip
# XRPUSDT-5m-2024-12.zip: 100%|██████████| 398k/398k [00:00<00:00, 715kB/s]
# ✅ 下载完成: XRPUSDT-5m-2024-12.zip
# XRPUSDT-5m-2025-01.zip: 100%|██████████| 397k/397k [00:00<00:00, 705kB/s]
# ✅ 下载完成: XRPUSDT-5m-2025-01.zip
# XRPUSDT-5m-2025-02.zip: 100%|██████████| 357k/357k [00:00<00:00, 834kB/s]
# ✅ 下载完成: XRPUSDT-5m-2025-02.zip
# XRPUSDT-5m-2025-03.zip: 100%|██████████| 390k/390k [00:00<00:00, 2.91MB/s]
# ✅ 下载完成: XRPUSDT-5m-2025-03.zip
# XRPUSDT-5m-2025-04.zip: 100%|██████████| 382k/382k [00:00<00:00, 827kB/s]
# ✅ 下载完成: XRPUSDT-5m-2025-04.zip
# XRPUSDT-5m-2025-05.zip: 100%|██████████| 405k/405k [00:00<00:00, 719kB/s]
# ✅ 下载完成: XRPUSDT-5m-2025-05.zip
# XRPUSDT-5m-2025-06.zip: 100%|██████████| 386k/386k [00:00<00:00, 695kB/s]
# ✅ 下载完成: XRPUSDT-5m-2025-06.zip
# XRPUSDT-5m-2025-07.zip: 100%|██████████| 414k/414k [00:00<00:00, 738kB/s]
# ✅ 下载完成: XRPUSDT-5m-2025-07.zip
# XRPUSDT-5m-2025-08.zip: 100%|██████████| 410k/410k [00:00<00:00, 742kB/s]
# ✅ 下载完成: XRPUSDT-5m-2025-08.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/XRPUSDT-5m-2024-09.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/XRPUSDT-5m-2024-10.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/XRPUSDT-5m-2024-11.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/XRPUSDT-5m-2024-12.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/XRPUSDT-5m-2025-01.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/XRPUSDT-5m-2025-02.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/XRPUSDT-5m-2025-03.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/XRPUSDT-5m-2025-04.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/XRPUSDT-5m-2025-05.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/XRPUSDT-5m-2025-06.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/XRPUSDT-5m-2025-07.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/XRPUSDT-5m-2025-08.zip
# 新下载数据条数: 105120 行
# 首次创建数据，总条数: 105120 行
# ✅ 数据已保存到 /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/XRPUSDT_klines_5m.csv
# ✅ 数据已写入数据库 XRPUSDT_klines_5m
#
# 合并后数据预览:
#                index      Open Time    Open    High     Low   Close    Volume  \
# Close Time
# 1725149099999      0  1725148800000  0.5662  0.5663  0.5660  0.5663  364623.0
# 1725149399999      1  1725149100000  0.5663  0.5667  0.5662  0.5663  150799.0
# 1725149699999      2  1725149400000  0.5663  0.5664  0.5661  0.5661   83930.0
# 1725149999999      3  1725149700000  0.5662  0.5663  0.5659  0.5659   96048.0
# 1725150299999      4  1725150000000  0.5659  0.5660  0.5659  0.5659   78988.0
#
#                Quote Asset Volume  Number of Trades  Taker Buy Base Volume  \
# Close Time
# 1725149099999         206435.9906               778               110349.0
# 1725149399999          85417.3559               475                79264.0
# 1725149699999          47524.0113               198                16502.0
# 1725149999999          54376.0468               431                46361.0
# 1725150299999          44700.2708               157                 9616.0
#
#                Taker Buy Quote Volume  Ignore
# Close Time
# 1725149099999              62477.5216       0
# 1725149399999              44896.6104       0
# 1725149699999               9345.7504       0
# 1725149999999              26247.4721       0
# 1725150299999               5442.6560       0
#
# 🚀 开始处理 DOGEUSDT …
# 1725163200000000 1756612800000000
# 数据库中没有 DOGEUSDT_klines_5m 的数据
# 📥 需要下载新数据来填补数据缺口
#   下载数据: 2024-09-01 到 2025-08-31
# 数据库中没有 DOGEUSDT_klines_5m 的数据
# DOGEUSDT-5m-2024-09.zip: 100%|██████████| 370k/370k [00:00<00:00, 673kB/s]
# ✅ 下载完成: DOGEUSDT-5m-2024-09.zip
# DOGEUSDT-5m-2024-10.zip: 100%|██████████| 394k/394k [00:00<00:00, 792kB/s]
# ✅ 下载完成: DOGEUSDT-5m-2024-10.zip
# DOGEUSDT-5m-2024-11.zip: 100%|██████████| 413k/413k [00:00<00:00, 771kB/s]
# ✅ 下载完成: DOGEUSDT-5m-2024-11.zip
# DOGEUSDT-5m-2024-12.zip: 100%|██████████| 420k/420k [00:00<00:00, 750kB/s]
# ✅ 下载完成: DOGEUSDT-5m-2024-12.zip
# DOGEUSDT-5m-2025-01.zip: 100%|██████████| 416k/416k [00:00<00:00, 666kB/s]
# ✅ 下载完成: DOGEUSDT-5m-2025-01.zip
# DOGEUSDT-5m-2025-02.zip: 100%|██████████| 369k/369k [00:00<00:00, 665kB/s]
# ✅ 下载完成: DOGEUSDT-5m-2025-02.zip
# DOGEUSDT-5m-2025-03.zip: 100%|██████████| 401k/401k [00:00<00:00, 710kB/s]
# ✅ 下载完成: DOGEUSDT-5m-2025-03.zip
# DOGEUSDT-5m-2025-04.zip: 100%|██████████| 384k/384k [00:00<00:00, 684kB/s]
# ✅ 下载完成: DOGEUSDT-5m-2025-04.zip
# DOGEUSDT-5m-2025-05.zip: 100%|██████████| 404k/404k [00:00<00:00, 721kB/s]
# ✅ 下载完成: DOGEUSDT-5m-2025-05.zip
# DOGEUSDT-5m-2025-06.zip: 100%|██████████| 380k/380k [00:00<00:00, 907kB/s]
# ✅ 下载完成: DOGEUSDT-5m-2025-06.zip
# DOGEUSDT-5m-2025-07.zip: 100%|██████████| 405k/405k [00:00<00:00, 725kB/s]
# ✅ 下载完成: DOGEUSDT-5m-2025-07.zip
# DOGEUSDT-5m-2025-08.zip: 100%|██████████| 405k/405k [00:00<00:00, 665kB/s]
# ✅ 下载完成: DOGEUSDT-5m-2025-08.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/DOGEUSDT-5m-2024-09.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/DOGEUSDT-5m-2024-10.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/DOGEUSDT-5m-2024-11.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/DOGEUSDT-5m-2024-12.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/DOGEUSDT-5m-2025-01.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/DOGEUSDT-5m-2025-02.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/DOGEUSDT-5m-2025-03.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/DOGEUSDT-5m-2025-04.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/DOGEUSDT-5m-2025-05.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/DOGEUSDT-5m-2025-06.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/DOGEUSDT-5m-2025-07.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/DOGEUSDT-5m-2025-08.zip
# 新下载数据条数: 105120 行
# 首次创建数据，总条数: 105120 行
# ✅ 数据已保存到 /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/DOGEUSDT_klines_5m.csv
# ✅ 数据已写入数据库 DOGEUSDT_klines_5m
#
# 合并后数据预览:
#                index      Open Time     Open     High      Low    Close  \
# Close Time
# 1725149099999      0  1725148800000  0.10128  0.10134  0.10127  0.10134
# 1725149399999      1  1725149100000  0.10134  0.10148  0.10133  0.10146
# 1725149699999      2  1725149400000  0.10145  0.10149  0.10143  0.10147
# 1725149999999      3  1725149700000  0.10147  0.10153  0.10138  0.10138
# 1725150299999      4  1725150000000  0.10139  0.10139  0.10120  0.10120
#
#                   Volume  Quote Asset Volume  Number of Trades  \
# Close Time
# 1725149099999   309743.0         31375.29047               644
# 1725149399999   390397.0         39595.07109               427
# 1725149699999  1054934.0        107033.46727               499
# 1725149999999   279403.0         28352.73283               459
# 1725150299999   212857.0         21555.11086               282
#
#                Taker Buy Base Volume  Taker Buy Quote Volume  Ignore
# Close Time
# 1725149099999               208486.0             21119.08608       0
# 1725149399999               369735.0             37499.56138       0
# 1725149699999               783081.0             79450.98696       0
# 1725149999999               129505.0             13144.59364       0
# 1725150299999                15243.0              1543.98179       0
#
# 🚀 开始处理 PEPEUSDT …
# 1725163200000000 1756612800000000
# 数据库中没有 PEPEUSDT_klines_5m 的数据
# 📥 需要下载新数据来填补数据缺口
#   下载数据: 2024-09-01 到 2025-08-31
# 数据库中没有 PEPEUSDT_klines_5m 的数据
# PEPEUSDT-5m-2024-09.zip: 100%|██████████| 404k/404k [00:00<00:00, 721kB/s]
# ✅ 下载完成: PEPEUSDT-5m-2024-09.zip
# PEPEUSDT-5m-2024-10.zip: 100%|██████████| 426k/426k [00:00<00:00, 764kB/s]
# ✅ 下载完成: PEPEUSDT-5m-2024-10.zip
# PEPEUSDT-5m-2024-11.zip: 100%|██████████| 431k/431k [00:00<00:00, 797kB/s]
# ✅ 下载完成: PEPEUSDT-5m-2024-11.zip
# PEPEUSDT-5m-2024-12.zip: 100%|██████████| 444k/444k [00:00<00:00, 791kB/s]
# ✅ 下载完成: PEPEUSDT-5m-2024-12.zip
# PEPEUSDT-5m-2025-01.zip: 100%|██████████| 433k/433k [00:00<00:00, 764kB/s]
# ✅ 下载完成: PEPEUSDT-5m-2025-01.zip
# PEPEUSDT-5m-2025-02.zip: 100%|██████████| 385k/385k [00:00<00:00, 694kB/s]
# ✅ 下载完成: PEPEUSDT-5m-2025-02.zip
# PEPEUSDT-5m-2025-03.zip: 100%|██████████| 421k/421k [00:00<00:00, 758kB/s]
# ✅ 下载完成: PEPEUSDT-5m-2025-03.zip
# PEPEUSDT-5m-2025-04.zip: 100%|██████████| 405k/405k [00:00<00:00, 719kB/s]
# ✅ 下载完成: PEPEUSDT-5m-2025-04.zip
# PEPEUSDT-5m-2025-05.zip: 100%|██████████| 433k/433k [00:00<00:00, 779kB/s]
# ✅ 下载完成: PEPEUSDT-5m-2025-05.zip
# PEPEUSDT-5m-2025-06.zip: 100%|██████████| 408k/408k [00:00<00:00, 729kB/s]
# ✅ 下载完成: PEPEUSDT-5m-2025-06.zip
# PEPEUSDT-5m-2025-07.zip: 100%|██████████| 426k/426k [00:00<00:00, 2.58MB/s]
# ✅ 下载完成: PEPEUSDT-5m-2025-07.zip
# PEPEUSDT-5m-2025-08.zip: 100%|██████████| 415k/415k [00:00<00:00, 737kB/s]
# ✅ 下载完成: PEPEUSDT-5m-2025-08.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/PEPEUSDT-5m-2024-09.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/PEPEUSDT-5m-2024-10.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/PEPEUSDT-5m-2024-11.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/PEPEUSDT-5m-2024-12.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/PEPEUSDT-5m-2025-01.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/PEPEUSDT-5m-2025-02.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/PEPEUSDT-5m-2025-03.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/PEPEUSDT-5m-2025-04.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/PEPEUSDT-5m-2025-05.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/PEPEUSDT-5m-2025-06.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/PEPEUSDT-5m-2025-07.zip
# 🗑️ 删除临时文件: /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/PEPEUSDT-5m-2025-08.zip
# 新下载数据条数: 105120 行
# 首次创建数据，总条数: 105120 行
# ✅ 数据已保存到 /Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw_tp/PEPEUSDT_klines_5m.csv
# ✅ 数据已写入数据库 PEPEUSDT_klines_5m
#
# 合并后数据预览:
#                index      Open Time      Open      High       Low     Close  \
# Close Time
# 1725149099999      0  1725148800000  0.000008  0.000008  0.000008  0.000008
# 1725149399999      1  1725149100000  0.000008  0.000008  0.000008  0.000008
# 1725149699999      2  1725149400000  0.000008  0.000008  0.000008  0.000008
# 1725149999999      3  1725149700000  0.000008  0.000008  0.000008  0.000008
# 1725150299999      4  1725150000000  0.000008  0.000008  0.000008  0.000008
#
#                      Volume  Quote Asset Volume  Number of Trades  \
# Close Time
# 1725149099999  1.509736e+10       114588.408402               699
# 1725149399999  1.107199e+10        84352.899081               492
# 1725149699999  1.287226e+10        98213.991347               658
# 1725149999999  1.343432e+10       102499.457667               496
# 1725150299999  1.691194e+10       128694.605025               606
#
#                Taker Buy Base Volume  Taker Buy Quote Volume  Ignore
# Close Time
# 1725149099999           5.521106e+09            41911.188826       0
# 1725149399999           9.645999e+09            73494.657167       0
# 1725149699999           6.706432e+09            51172.362471       0
# 1725149999999           8.248056e+09            62933.081113       0
# 1725150299999           4.373346e+08             3328.996141       0

# %%
major_list = ["BTCUSDT", "ETHUSDT", "LTCUSDT", "XRPUSDT", "ADAUSDT", "SOLUSDT", "BNBUSDT", "LINKUSDT"]
meme_list = ["DOGEUSDT", "SHIBUSDT", "PEPEUSDT", "PENGUUSDT","BONKUSDT", "TRUMPUSDT", "SPXUSDT", "FLOKIUSDT", "WIFUSDT"]

# %%
# by million

volume_dict = {
    "BTCUSDT": 19.92, 
    "ETHUSDT": 120.7, 
    "XRPUSDT": 59.77*1000,
    "BNBUSDT": 139.18, 
    "SOLUSDT": 543.03, 
    "ADAUSDT": 35.79*1000,
    "LINKUSDT": 678.09, 
    "LTCUSDT": 76.31,

    "DOGEUSDT": 151*1000, 
    "SHIBUSDT": 589.24*1000000, 
    "PEPEUSDT": 420.68*1000000, 
    "PENGUUSDT": 62.86*1000,
    "BONKUSDT": 81.21*1000000, 
    # "TRUMPUSDT": 199.99, 
    "SPXUSDT": 930.99, 
    "FLOKIUSDT": 9.53*1000000, 
    "WIFUSDT": 998.83
    }

# %%
from pathlib import Path
import pandas as pd

output_dir = "/Users/lizeyu/Desktop/qoc/tmp/raw/5m_klines_raw"
output_path = Path(output_dir)

major_1st_mktval = None
major_2st_mktval = None
major_3st_mktval = None
major_rest_mktval = None
meme_1st_mktval = None
meme_2st_mktval = None
meme_3st_mktval = None
meme_rest_mktval = None



major_mktval_dict, meme_mktval_dict = {}, {}

common_index = None   # 用来存放所有文件的共同 Close Time

for file in output_path.iterdir():
    if file.is_file() and file.suffix.lower() == ".csv":
        df = pd.read_csv(file, encoding="utf-8")
        df.columns = df.columns.str.strip().str.replace("\ufeff","",regex=False)

        if 'Close' not in df.columns or 'Close Time' not in df.columns:
            print(f"⚠️ 跳过无 Close 或 Close Time 的文件: {file.name}")
            continue

        df.set_index('Close Time', inplace=True)
        symbol = file.stem.split('_')[0]

        # === 1️⃣ 更新共同 index ===
        if common_index is None:
            common_index = df.index
        else:
            common_index = common_index.intersection(df.index)

        # === 2️⃣ 计算总市值 ===
        close_ts = df['Close']
        tot_volume = volume_dict.get(symbol, 0)
        tot_value = close_ts * tot_volume / 1e6   # 百万美元

        if symbol in major_list:
            if symbol == "BTCUSDT":
                major_1st_mktval = tot_value
            elif symbol == "ETHUSDT":
                major_2st_mktval = tot_value
            elif symbol == "XRPUSDT":
                major_3st_mktval = tot_value
            
            else:
                major_rest_mktval = (
                    major_rest_mktval.add(tot_value, fill_value=0)
                    if major_rest_mktval is not None else tot_value.copy()
                )
            major_mktval_dict[symbol] = tot_value

        elif symbol in meme_list:
            if symbol == "DOGEUSDT":
                meme_1st_mktval = tot_value
            elif symbol == "SHIBUSDT":
                meme_2st_mktval = tot_value
            elif symbol == "PEPEUSDT":
                meme_3st_mktval = tot_value
            else:
                meme_rest_mktval = (
                    meme_rest_mktval.add(tot_value, fill_value=0)
                    if meme_rest_mktval is not None else tot_value.copy()
                )
            meme_mktval_dict[symbol] = tot_value

# === 3️⃣ 循环结束后，对所有结果裁剪到共同 index ===
if common_index is not None:
    if major_1st_mktval is not None:
        major_1st_mktval = major_1st_mktval.reindex(common_index)
    if major_rest_mktval is not None:
        major_rest_mktval = major_rest_mktval.reindex(common_index)
    if meme_1st_mktval is not None:
        meme_1st_mktval = meme_1st_mktval.reindex(common_index)
    if meme_rest_mktval is not None:
        meme_rest_mktval = meme_rest_mktval.reindex(common_index)
    if major_2st_mktval is not None:
        major_2st_mktval = major_2st_mktval.reindex(common_index)
    if major_3st_mktval is not None:
        major_3st_mktval = major_3st_mktval.reindex(common_index)
    if meme_2st_mktval is not None:
        meme_2st_mktval = meme_2st_mktval.reindex(common_index)
    if meme_3st_mktval is not None:
        meme_3st_mktval = meme_3st_mktval.reindex(common_index)

print("✅ 共同 index 长度:", len(common_index))
# Out:
# ✅ 共同 index 长度: 55770

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 7))
for symbol, mktval in major_mktval_dict.items():
    plt.plot(mktval.index, mktval, label=symbol, color='blue' if symbol == 'BTCUSDT' else 'green')
plt.plot(major_rest_mktval.index, major_rest_mktval, label="rest_major_marketcap", color='purple', linestyle='--')
plt.title("Major Assets Market Capitalization Over Time")
plt.xlabel("Time")
plt.ylabel("Market Capitalization (Million USD)")
plt.legend()
plt.grid()
plt.show()
plt.close()


plt.figure(figsize=(14, 7))
for symbol, mktval in meme_mktval_dict.items():
    plt.plot(mktval.index, mktval, label=symbol, color='orange' if symbol == 'DOGEUSDT' else 'red')
plt.plot(meme_rest_mktval.index, meme_rest_mktval, label="rest_meme_marketcap", color='purple', linestyle='--')
plt.title("MEME Assets Market Capitalization Over Time")
plt.xlabel("Time")
plt.ylabel("Market Capitalization (Million USD)")
plt.legend()
plt.grid()
plt.show()
plt.close()

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

def lead_lag_correlation(series1: pd.Series, series2: pd.Series, max_lag: int = 24, interval: int = 3): 
  """
  Measure the lead-lag correlation between two time series and visualize the effect of shifting timestamps.

  Parameters:
    series1 (pd.Series): The first time series.
    series2 (pd.Series): The second time series.
    max_lag (int): The maximum number of timestamps to shift forward and backward.

  Returns:
    pd.Series: A series containing the correlation values for each lag/lead.
  """
  correlations = {}

  for lag in range(-max_lag, max_lag + 1):
    if lag < 0:
      # series1 leads series2
      shifted_series2 = series2.shift(-lag*interval)
      corr = series1.corr(shifted_series2)
    elif lag > 0:
      # series2 leads series1
      shifted_series1 = series1.shift(lag*interval)
      corr = shifted_series1.corr(series2)
    else:
      # No lag
      corr = series1.corr(series2)
    
    correlations[lag] = corr

  # Convert to pandas Series for easier handling
  correlation_series = pd.Series(correlations)

  # Plot the results
  plt.figure(figsize=(10, 6))
  plt.plot(correlation_series.index, correlation_series.values, marker='o', linestyle='-')
  plt.axhline(0, color='gray', linestyle='--', linewidth=1)
  plt.title("Lead-Lag Correlation")
  plt.xlabel("Lag (timestamps)")
  plt.ylabel("Correlation")
  plt.grid()
  plt.show()

  return correlation_series

# %%
# 计算 major_1st_mktval 相隔12个时间戳的涨幅
major_1st_returns = major_1st_mktval.pct_change(periods=60)

# 计算 major_rest_mktval 相隔12个时间戳的涨幅
major_1st_returns = major_1st_mktval.pct_change(periods=60)

# 使用涨幅序列作为 lead_lag_correlation 的输入
lead_lag_correlation(major_1st_returns, major_1st_returns, max_lag=24, interval=30)
# Out:
# -24   -0.051983
# -23   -0.041944
# -22   -0.007588
# -21    0.045812
# -20    0.067287
# -19    0.048064
# -18    0.007316
# -17   -0.019061
# -16    0.005260
# -15    0.030948
# -14    0.029387
# -13    0.016794
# -12   -0.002874
# -11   -0.007604
# -10   -0.053674
# -9    -0.125556
# -8    -0.103432
# -7    -0.053545
# -6    -0.052568
# -5    -0.043750
# -4    -0.022879
# -3    -0.006416
# -2     0.004299
# -1     0.502977
#  0     1.000000
#  1     0.502977
#  2     0.004299
#  3    -0.006416
#  4    -0.022879
#  5    -0.043750
#  6    -0.052568
#  7    -0.053545
#  8    -0.103432
#  9    -0.125556
#  10   -0.053674
#  11   -0.007604
#  12   -0.002874
#  13    0.016794
#  14    0.029387
#  15    0.030948
#  16    0.005260
#  17   -0.019061
#  18    0.007316
#  19    0.048064
#  20    0.067287
#  21    0.045812
#  22   -0.007588
#  23   -0.041944
#  24   -0.051983
# dtype: float64

# %%
# 计算 major_1st_mktval 相隔12个时间戳的涨幅
major_1st_returns = major_1st_mktval.pct_change(periods=60)

# 计算 major_rest_mktval 相隔12个时间戳的涨幅
major_rest_returns = major_rest_mktval.pct_change(periods=60)

# 使用涨幅序列作为 lead_lag_correlation 的输入
lead_lag_correlation(major_1st_returns, major_rest_returns, max_lag=24, interval=30)
# Out:
# -24   -0.044011
# -23   -0.036674
# -22   -0.011758
# -21    0.042613
# -20    0.053833
# -19    0.027218
# -18    0.012714
# -17   -0.003445
# -16    0.002282
# -15    0.022672
# -14    0.007188
# -13   -0.016989
# -12   -0.024281
# -11   -0.017033
# -10   -0.058754
# -9    -0.118300
# -8    -0.078260
# -7    -0.043868
# -6    -0.053464
# -5    -0.029336
# -4    -0.006110
# -3     0.007214
# -2     0.032896
# -1     0.461558
#  0     0.840769
#  1     0.400161
#  2     0.009005
#  3     0.007348
#  4    -0.022390
#  5    -0.043092
#  6    -0.053526
#  7    -0.056738
#  8    -0.086220
#  9    -0.088322
#  10   -0.022823
#  11    0.005233
#  12   -0.007500
#  13    0.009454
#  14    0.031178
#  15    0.030979
#  16    0.008081
#  17   -0.005219
#  18    0.012917
#  19    0.030744
#  20    0.043014
#  21    0.046866
#  22    0.027469
#  23   -0.002874
#  24   -0.037940
# dtype: float64

# %%
# 计算 major_1st_mktval 相隔12个时间戳的涨幅
meme_1st_returns = meme_1st_mktval.pct_change(periods=60)

# 计算 major_rest_mktval 相隔12个时间戳的涨幅
meme_rest_returns = meme_rest_mktval.pct_change(periods=60)

# 使用涨幅序列作为 lead_lag_correlation 的输入
lead_lag_correlation(meme_1st_returns, meme_rest_returns, max_lag=24, interval=30)
# Out:
# -24   -0.015868
# -23   -0.015500
# -22   -0.016758
# -21    0.005652
# -20    0.000726
# -19   -0.001919
# -18    0.028560
# -17    0.025895
# -16    0.007419
# -15    0.014345
# -14    0.026422
# -13    0.026606
# -12    0.023151
# -11    0.041403
# -10    0.024402
# -9    -0.043047
# -8    -0.052880
# -7    -0.023719
# -6    -0.019650
# -5    -0.015930
# -4     0.002545
# -3     0.024690
# -2     0.028216
# -1     0.404872
#  0     0.794070
#  1     0.424780
#  2     0.045295
#  3     0.017699
#  4    -0.016660
#  5    -0.018041
#  6    -0.015559
#  7    -0.042779
#  8    -0.090577
#  9    -0.081851
#  10    0.004063
#  11    0.051796
#  12    0.054148
#  13    0.062628
#  14    0.050616
#  15    0.013669
#  16   -0.012853
#  17   -0.004410
#  18    0.003810
#  19   -0.010285
#  20    0.001434
#  21    0.012730
#  22   -0.010267
#  23   -0.020819
#  24   -0.038871
# dtype: float64

# %%
_1st_major_to_meme_ratio = major_1st_mktval / meme_1st_mktval
_2st_major_to_meme_ratio = major_2st_mktval / meme_2st_mktval
_3st_major_to_meme_ratio = major_3st_mktval / meme_3st_mktval
rest_major_to_meme_ratio = major_rest_mktval / meme_rest_mktval

# %%
plt.figure(figsize=(14, 7))
plt.plot(_1st_major_to_meme_ratio.index, _1st_major_to_meme_ratio, label="1st_major_to_meme_ratio", color='blue')
plt.plot(rest_major_to_meme_ratio.index, rest_major_to_meme_ratio, label="rest_major_to_meme_ratio", color='orange')
plt.title("Major to MEME Market Capitalization Ratio Over Time")
plt.xlabel("Time")
plt.ylabel("Market Capitalization Ratio")
plt.legend()
plt.grid()
plt.show()
plt.close()

# %%
# 计算 major_1st_mktval 相隔12个时间戳的涨幅
_1st_m2m_returns = _1st_major_to_meme_ratio.pct_change(periods=96)

# 计算 major_rest_mktval 相隔12个时间戳的涨幅
_2st_m2m_returns = _3st_major_to_meme_ratio.pct_change(periods=96)

# 使用涨幅序列作为 lead_lag_correlation 的输入
lead_lag_correlation(_1st_m2m_returns, _2st_m2m_returns, max_lag=24, interval=36)
# Out:
# -24    0.007642
# -23    0.001402
# -22   -0.016773
# -21   -0.035575
# -20   -0.039912
# -19   -0.018738
# -18   -0.009126
# -17   -0.009850
# -16   -0.008970
# -15    0.023639
# -14    0.040233
# -13    0.035769
# -12   -0.001177
# -11   -0.001419
# -10    0.007273
# -9     0.039849
# -8     0.053595
# -7     0.052980
# -6     0.033438
# -5     0.033099
# -4     0.026166
# -3     0.021369
# -2     0.094579
# -1     0.231097
#  0     0.379542
#  1     0.261401
#  2     0.093392
#  3    -0.023196
#  4    -0.027323
#  5    -0.027947
#  6    -0.058459
#  7    -0.042223
#  8     0.017437
#  9     0.082501
#  10    0.115831
#  11    0.100428
#  12    0.050192
#  13   -0.005572
#  14   -0.042196
#  15   -0.052313
#  16   -0.074318
#  17   -0.089108
#  18   -0.080260
#  19   -0.046255
#  20   -0.010768
#  21    0.003309
#  22    0.021227
#  23    0.033457
#  24    0.022228
# dtype: float64

# %%
# major_1st_mktval
# major_rest_mktval
# meme_1st_mktval
# meme_rest_mktval


# 计算 major_1st_mktval 相隔12个时间戳的涨幅
_1st_m2m_returns = major_1st_mktval.pct_change(periods=96)

# 计算 major_rest_mktval 相隔12个时间戳的涨幅
rest_m2m_returns = major_rest_mktval.pct_change(periods=96)

# 使用涨幅序列作为 lead_lag_correlation 的输入
lead_lag_correlation(_1st_m2m_returns, rest_m2m_returns, max_lag=24, interval=96)
# Out:
# -24   -0.028680
# -23   -0.051513
# -22   -0.021038
# -21    0.049918
# -20    0.054615
# -19    0.020870
# -18   -0.071204
# -17   -0.020004
# -16   -0.025908
# -15    0.003563
# -14   -0.009627
# -13   -0.027617
# -12    0.010011
# -11    0.014476
# -10    0.018909
# -9    -0.040172
# -8    -0.004598
# -7    -0.019891
# -6     0.049256
# -5     0.010314
# -4    -0.016365
# -3    -0.108459
# -2    -0.082149
# -1     0.011599
#  0     0.850300
#  1    -0.014952
#  2    -0.094052
#  3    -0.072095
#  4     0.017016
#  5     0.021844
#  6     0.048600
#  7     0.015296
#  8    -0.035836
#  9    -0.071704
#  10   -0.002071
#  11    0.020544
#  12   -0.030177
#  13   -0.015028
#  14   -0.019839
#  15   -0.016267
#  16   -0.027945
#  17   -0.002491
#  18   -0.078419
#  19    0.043412
#  20    0.066002
#  21    0.052926
#  22   -0.023172
#  23   -0.054122
#  24   -0.027733
# dtype: float64
