# %%
import os
import shutil
import sys
from pathlib import Path

# 替换此行
# sys.path.insert(0, os.path.abspath(os.path.join(os.path.dirname(__file__), "../../src")))

# 方法1：使用当前工作目录
notebook_dir = os.getcwd()  # 获取当前工作目录
src_path = os.path.abspath(os.path.join(notebook_dir, "../../src"))
sys.path.insert(0, src_path)


import qoc

db: str = qoc.data_dir("database").as_uri().replace("file://", "lmdb://")


online: bool = False
symbols: list[str] = ["BTCUSDT"]
# , "ETHUSDT", "LTCUSDT", "XRPUSDT", "ADAUSDT", "SOLUSDT", "BNBUSDT", "LINKUSDT",
#             "DOGEUSDT", "SHIBUSDT", "PEPEUSDT", "PENGUUSDT","BONKUSDT", "TRUMPUSDT", "SPXUSDT", "FLOKIUSDT", "WIFUSDT"]


# symbols: list[str] = ["BTCUSDT", "DOGEUSDT"]
transaction_fee: float = 0.01  # 交易费用为0.1%
interval: str = "5m"
start_date: str = "2024-01-01"
end_date: str = "2025-01-01"
output_dir: str = "tmp/raw/5m_klines_raw_tp"


offline_db_path = Path("strategies/grid-strategy/data/database_tp/")
if offline_db_path.exists():
    # logger.info(f"删除现有数据库文件夹: {offline_db_path}")
    shutil.rmtree(offline_db_path)


import arcticdb as adb
from offline_fetch import fetch_for_offline

uri = "lmdb://strategies/grid-strategy/data/database_offline_tp/"

ac = adb.Arctic(uri)

qoc_library = ac.get_library("market", create_if_missing=True)

fetch_for_offline(symbols, interval, start_date, end_date, output_dir, qoc_library)
# Out:
# 🚀 开始处理 BTCUSDT …
# 1704038400000000 1735660800000000
# 当前索引: Index([   1704067499999,    1704067799999,    1704068099999,    1704068399999,
#           1704068699999,    1704068999999,    1704069299999,    1704069599999,
#           1704069899999,    1704070199999,
#        ...
#        1738365299999999, 1738365599999999, 1738365899999999, 1738366199999999,
#        1738366499999999, 1738366799999999, 1738367099999999, 1738367399999999,
#        1738367699999999, 1738367999999999],
#       dtype='int64', name='Close Time', length=114336)
# 1704067499999 1738367999999999
# 数据库中的整体时间范围: 1970-01-21 01:21:07 到 2025-02-01 07:59:59
# 请求的时间范围: 2024-01-01 00:00:00 到 2025-01-01 00:00:00
# 正在逐条检查数据连续性...
# ⚠️ 过滤后的数据为空，可能是日期范围问题
# 📥 需要下载新数据来填补数据缺口
#   下载数据: 2024-01-01 到 2025-01-01
# 当前索引类型: <class 'pandas.core.indexes.base.Index'>
# 当前列: ['index', 'Open Time', 'Open', 'High', 'Low', 'Close', 'Volume', 'Quote Asset Volume', 'Number of Trades', 'Taker Buy Base Volume', 'Taker Buy Quote Volume', 'Ignore']
# 'Close Time'不在列中，可能已经是索引或不存在
# 现有数据条数: 114336 行
# 20251107 11:33:38.703296 791859 W arcticdb | LMDB path at /home/liblaf/github/RockyLiii/Quant-on-Crypto/strategies/rev-strategy/strategies/grid-strategy/data/database_offline_tp/ has already been opened in this process which is not supported by LMDB. You should only open a single Arctic instance over a given LMDB path. To continue safely, you should delete this Arctic instance and any others over the LMDB path in this process and then try again. Current process ID=[791859]
# BTCUSDT-5m-2024-01.zip: 100%|██████████| 465k/465k [00:00<00:00, 2.02MB/s]
# ✅ 下载完成: BTCUSDT-5m-2024-01.zip
# BTCUSDT-5m-2024-02.zip: 100%|██████████| 434k/434k [00:00<00:00, 2.18MB/s]
# ✅ 下载完成: BTCUSDT-5m-2024-02.zip
# BTCUSDT-5m-2024-03.zip: 100%|██████████| 474k/474k [00:00<00:00, 2.70MB/s]
# ✅ 下载完成: BTCUSDT-5m-2024-03.zip
# BTCUSDT-5m-2024-04.zip: 100%|██████████| 455k/455k [00:00<00:00, 2.27MB/s]
# ✅ 下载完成: BTCUSDT-5m-2024-04.zip
# BTCUSDT-5m-2024-05.zip: 100%|██████████| 463k/463k [00:00<00:00, 2.00MB/s]
# ✅ 下载完成: BTCUSDT-5m-2024-05.zip
# BTCUSDT-5m-2024-06.zip: 100%|██████████| 440k/440k [00:00<00:00, 2.30MB/s]
# ✅ 下载完成: BTCUSDT-5m-2024-06.zip
# BTCUSDT-5m-2024-07.zip: 100%|██████████| 461k/461k [00:00<00:00, 2.41MB/s]
# ✅ 下载完成: BTCUSDT-5m-2024-07.zip
# BTCUSDT-5m-2024-08.zip: 100%|██████████| 464k/464k [00:00<00:00, 2.40MB/s]
# ✅ 下载完成: BTCUSDT-5m-2024-08.zip
# BTCUSDT-5m-2024-09.zip: 100%|██████████| 442k/442k [00:00<00:00, 2.64MB/s]
# ✅ 下载完成: BTCUSDT-5m-2024-09.zip
# BTCUSDT-5m-2024-10.zip: 100%|██████████| 459k/459k [00:00<00:00, 2.59MB/s]
# ✅ 下载完成: BTCUSDT-5m-2024-10.zip
# BTCUSDT-5m-2024-11.zip: 100%|██████████| 459k/459k [00:00<00:00, 2.67MB/s]
# ✅ 下载完成: BTCUSDT-5m-2024-11.zip
# BTCUSDT-5m-2024-12.zip: 100%|██████████| 475k/475k [00:00<00:00, 2.95MB/s]
# ✅ 下载完成: BTCUSDT-5m-2024-12.zip
# BTCUSDT-5m-2025-01.zip: 100%|██████████| 478k/478k [00:00<00:00, 2.20MB/s]
# ✅ 下载完成: BTCUSDT-5m-2025-01.zip
# 🗑️ 删除临时文件: tmp/raw/5m_klines_raw_tp/BTCUSDT-5m-2024-01.zip
# 🗑️ 删除临时文件: tmp/raw/5m_klines_raw_tp/BTCUSDT-5m-2024-02.zip
# 🗑️ 删除临时文件: tmp/raw/5m_klines_raw_tp/BTCUSDT-5m-2024-03.zip
# 🗑️ 删除临时文件: tmp/raw/5m_klines_raw_tp/BTCUSDT-5m-2024-04.zip
# 🗑️ 删除临时文件: tmp/raw/5m_klines_raw_tp/BTCUSDT-5m-2024-05.zip
# 🗑️ 删除临时文件: tmp/raw/5m_klines_raw_tp/BTCUSDT-5m-2024-06.zip
# 🗑️ 删除临时文件: tmp/raw/5m_klines_raw_tp/BTCUSDT-5m-2024-07.zip
# 🗑️ 删除临时文件: tmp/raw/5m_klines_raw_tp/BTCUSDT-5m-2024-08.zip
# 🗑️ 删除临时文件: tmp/raw/5m_klines_raw_tp/BTCUSDT-5m-2024-09.zip
# 🗑️ 删除临时文件: tmp/raw/5m_klines_raw_tp/BTCUSDT-5m-2024-10.zip
# 🗑️ 删除临时文件: tmp/raw/5m_klines_raw_tp/BTCUSDT-5m-2024-11.zip
# 🗑️ 删除临时文件: tmp/raw/5m_klines_raw_tp/BTCUSDT-5m-2024-12.zip
# 🗑️ 删除临时文件: tmp/raw/5m_klines_raw_tp/BTCUSDT-5m-2025-01.zip
# 新下载数据条数: 114336 行
# 合并前总条数: 228672 行
# 合并后总条数: 114336 行
# 重复条数: 114336 行
# ✅ 数据已保存到 tmp/raw/5m_klines_raw_tp/BTCUSDT_klines_5m.csv
# ✅ 数据已写入数据库 BTCUSDT_klines_5m
#
# 合并后数据预览:
#                index      Open Time      Open      High       Low     Close  \
# Close Time
# 1704067499999      0  1704067200000  42283.58  42397.23  42261.02  42397.23
# 1704067799999      1  1704067500000  42397.22  42432.74  42385.26  42409.96
# 1704068099999      2  1704067800000  42409.97  42488.09  42409.96  42488.00
# 1704068399999      3  1704068100000  42488.00  42554.57  42458.58  42458.85
# 1704068699999      4  1704068400000  42458.85  42491.10  42445.84  42473.93
#
#                   Volume  Quote Asset Volume  Number of Trades  \
# Close Time
# 1704067499999  155.25731        6.572926e+06              6350
# 1704067799999  141.31102        5.993375e+06              5134
# 1704068099999  135.14249        5.738386e+06              5167
# 1704068399999  163.32541        6.943230e+06              6153
# 1704068699999  117.27112        4.979136e+06              3094
#
#                Taker Buy Base Volume  Taker Buy Quote Volume  Ignore
# Close Time
# 1704067499999              106.05732            4.490262e+06       0
# 1704067799999               69.45156            2.945452e+06       0
# 1704068099999               73.25966            3.110338e+06       0
# 1704068399999               82.81591            3.520689e+06       0
# 1704068699999               49.06278            2.083183e+06       0

# %%
major_list = [
    "BTCUSDT",
    "ETHUSDT",
    "LTCUSDT",
    "XRPUSDT",
    "ADAUSDT",
    "SOLUSDT",
    "BNBUSDT",
    "LINKUSDT",
]
meme_list = [
    "DOGEUSDT",
    "SHIBUSDT",
    "PEPEUSDT",
    "PENGUUSDT",
    "BONKUSDT",
    "TRUMPUSDT",
    "SPXUSDT",
    "FLOKIUSDT",
    "WIFUSDT",
]

# %%
# by million

volume_dict = {
    "BTCUSDT": 19.92,
    "ETHUSDT": 120.7,
    "XRPUSDT": 59.77 * 1000,
    "BNBUSDT": 139.18,
    "SOLUSDT": 543.03,
    "ADAUSDT": 35.79 * 1000,
    "LINKUSDT": 678.09,
    "LTCUSDT": 76.31,
    "DOGEUSDT": 151 * 1000,
    "SHIBUSDT": 589.24 * 1000000,
    "PEPEUSDT": 420.68 * 1000000,
    "PENGUUSDT": 62.86 * 1000,
    "BONKUSDT": 81.21 * 1000000,
    # "TRUMPUSDT": 199.99,
    "SPXUSDT": 930.99,
    "FLOKIUSDT": 9.53 * 1000000,
    "WIFUSDT": 998.83,
}

# %%
from pathlib import Path

import pandas as pd

output_dir = "tmp/raw/5m_klines_raw"
output_path = Path(output_dir)

major_1st_mktval = None
major_2st_mktval = None
major_3st_mktval = None
major_rest_mktval = None
meme_1st_mktval = None
meme_2st_mktval = None
meme_3st_mktval = None
meme_rest_mktval = None


major_mktval_dict, meme_mktval_dict = {}, {}

common_index = None  # 用来存放所有文件的共同 Close Time

for file in output_path.iterdir():
    if file.is_file() and file.suffix.lower() == ".csv":
        df = pd.read_csv(file, encoding="utf-8")
        df.columns = df.columns.str.strip().str.replace("\ufeff", "", regex=False)

        if "Close" not in df.columns or "Close Time" not in df.columns:
            print(f"⚠️ 跳过无 Close 或 Close Time 的文件: {file.name}")
            continue

        df.set_index("Close Time", inplace=True)
        symbol = file.stem.split("_")[0]

        # === 1️⃣ 更新共同 index ===
        if common_index is None:
            common_index = df.index
        else:
            common_index = common_index.intersection(df.index)

        # === 2️⃣ 计算总市值 ===
        close_ts = df["Close"]
        tot_volume = volume_dict.get(symbol, 0)
        tot_value = close_ts * tot_volume / 1e6  # 百万美元

        if symbol in major_list:
            if symbol == "BTCUSDT":
                major_1st_mktval = tot_value
            elif symbol == "ETHUSDT":
                major_2st_mktval = tot_value
            elif symbol == "XRPUSDT":
                major_3st_mktval = tot_value

            else:
                major_rest_mktval = (
                    major_rest_mktval.add(tot_value, fill_value=0)
                    if major_rest_mktval is not None
                    else tot_value.copy()
                )
            major_mktval_dict[symbol] = tot_value

        elif symbol in meme_list:
            if symbol == "DOGEUSDT":
                meme_1st_mktval = tot_value
            elif symbol == "SHIBUSDT":
                meme_2st_mktval = tot_value
            elif symbol == "PEPEUSDT":
                meme_3st_mktval = tot_value
            else:
                meme_rest_mktval = (
                    meme_rest_mktval.add(tot_value, fill_value=0)
                    if meme_rest_mktval is not None
                    else tot_value.copy()
                )
            meme_mktval_dict[symbol] = tot_value

# === 3️⃣ 循环结束后，对所有结果裁剪到共同 index ===
if common_index is not None:
    if major_1st_mktval is not None:
        major_1st_mktval = major_1st_mktval.reindex(common_index)
    if major_rest_mktval is not None:
        major_rest_mktval = major_rest_mktval.reindex(common_index)
    if meme_1st_mktval is not None:
        meme_1st_mktval = meme_1st_mktval.reindex(common_index)
    if meme_rest_mktval is not None:
        meme_rest_mktval = meme_rest_mktval.reindex(common_index)
    if major_2st_mktval is not None:
        major_2st_mktval = major_2st_mktval.reindex(common_index)
    if major_3st_mktval is not None:
        major_3st_mktval = major_3st_mktval.reindex(common_index)
    if meme_2st_mktval is not None:
        meme_2st_mktval = meme_2st_mktval.reindex(common_index)
    if meme_3st_mktval is not None:
        meme_3st_mktval = meme_3st_mktval.reindex(common_index)

print("✅ 共同 index 长度:", len(common_index))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 22
#      18 major_mktval_dict, meme_mktval_dict = {}, {}
#      20 common_index = None  # 用来存放所有文件的共同 Close Time
# ---> 22 for file in output_path.iterdir():
#      23     if file.is_file() and file.suffix.lower() == ".csv":
#      24         df = pd.read_csv(file, encoding="utf-8")
#
# File /usr/lib/python3.13/pathlib/_local.py:575, in Path.iterdir(self)
#     569 """Yield path objects of the directory contents.
#     570
#     571 The children are yielded in arbitrary order, and the
#     572 special entries '.' and '..' are not included.
#     573 """
#     574 root_dir = str(self)
# --> 575 with os.scandir(root_dir) as scandir_it:
#     576     paths = [entry.path for entry in scandir_it]
#     577 if root_dir == '.':
#
# FileNotFoundError: [Errno 2] No such file or directory: 'tmp/raw/5m_klines_raw'

# %%
import requests
import pandas as pd

url = "https://api.growthepie.xyz/v1/fundamentals_full.json"
response = requests.get(url)
df = pd.DataFrame(response.json())

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 7))
for symbol, mktval in major_mktval_dict.items():
    plt.plot(
        mktval.index,
        mktval,
        label=symbol,
        color="blue" if symbol == "BTCUSDT" else "green",
    )
plt.plot(
    major_rest_mktval.index,
    major_rest_mktval,
    label="rest_major_marketcap",
    color="purple",
    linestyle="--",
)
plt.title("Major Assets Market Capitalization Over Time")
plt.xlabel("Time")
plt.ylabel("Market Capitalization (Million USD)")
plt.legend()
plt.grid()
plt.show()
plt.close()


plt.figure(figsize=(14, 7))
for symbol, mktval in meme_mktval_dict.items():
    plt.plot(
        mktval.index,
        mktval,
        label=symbol,
        color="orange" if symbol == "DOGEUSDT" else "red",
    )
plt.plot(
    meme_rest_mktval.index,
    meme_rest_mktval,
    label="rest_meme_marketcap",
    color="purple",
    linestyle="--",
)
plt.title("MEME Assets Market Capitalization Over Time")
plt.xlabel("Time")
plt.ylabel("Market Capitalization (Million USD)")
plt.legend()
plt.grid()
plt.show()
plt.close()

# %%
import matplotlib.pyplot as plt
import pandas as pd


def lead_lag_correlation(
    series1: pd.Series, series2: pd.Series, max_lag: int = 24, interval: int = 3
):
    """Measure the lead-lag correlation between two time series and visualize the effect of shifting timestamps.

    Parameters:
      series1 (pd.Series): The first time series.
      series2 (pd.Series): The second time series.
      max_lag (int): The maximum number of timestamps to shift forward and backward.

    Returns:
      pd.Series: A series containing the correlation values for each lag/lead.
    """
    correlations = {}

    for lag in range(-max_lag, max_lag + 1):
        if lag < 0:
            # series1 leads series2
            shifted_series2 = series2.shift(-lag * interval)
            corr = series1.corr(shifted_series2)
        elif lag > 0:
            # series2 leads series1
            shifted_series1 = series1.shift(lag * interval)
            corr = shifted_series1.corr(series2)
        else:
            # No lag
            corr = series1.corr(series2)

        correlations[lag] = corr

    # Convert to pandas Series for easier handling
    correlation_series = pd.Series(correlations)

    # Plot the results
    plt.figure(figsize=(10, 6))
    plt.plot(
        correlation_series.index, correlation_series.values, marker="o", linestyle="-"
    )
    plt.axhline(0, color="gray", linestyle="--", linewidth=1)
    plt.title("Lead-Lag Correlation")
    plt.xlabel("Lag (timestamps)")
    plt.ylabel("Correlation")
    plt.grid()
    plt.show()

    return correlation_series

# %%
# 计算 major_1st_mktval 相隔12个时间戳的涨幅
major_1st_returns = major_1st_mktval.pct_change(periods=60)

# 计算 major_rest_mktval 相隔12个时间戳的涨幅
major_1st_returns = major_1st_mktval.pct_change(periods=60)

# 使用涨幅序列作为 lead_lag_correlation 的输入
lead_lag_correlation(major_1st_returns, major_1st_returns, max_lag=24, interval=30)

# %%
# 计算 major_1st_mktval 相隔12个时间戳的涨幅
major_1st_returns = major_1st_mktval.pct_change(periods=60)

# 计算 major_rest_mktval 相隔12个时间戳的涨幅
major_rest_returns = major_rest_mktval.pct_change(periods=60)

# 使用涨幅序列作为 lead_lag_correlation 的输入
lead_lag_correlation(major_1st_returns, major_rest_returns, max_lag=24, interval=30)

# %%
# 计算 major_1st_mktval 相隔12个时间戳的涨幅
meme_1st_returns = meme_1st_mktval.pct_change(periods=60)

# 计算 major_rest_mktval 相隔12个时间戳的涨幅
meme_rest_returns = meme_rest_mktval.pct_change(periods=60)

# 使用涨幅序列作为 lead_lag_correlation 的输入
lead_lag_correlation(meme_1st_returns, meme_rest_returns, max_lag=24, interval=30)

# %%
_1st_major_to_meme_ratio = major_1st_mktval / meme_1st_mktval
_2st_major_to_meme_ratio = major_2st_mktval / meme_2st_mktval
_3st_major_to_meme_ratio = major_3st_mktval / meme_3st_mktval
rest_major_to_meme_ratio = major_rest_mktval / meme_rest_mktval

# %%
plt.figure(figsize=(14, 7))
plt.plot(
    _1st_major_to_meme_ratio.index,
    _1st_major_to_meme_ratio,
    label="1st_major_to_meme_ratio",
    color="blue",
)
plt.plot(
    rest_major_to_meme_ratio.index,
    rest_major_to_meme_ratio,
    label="rest_major_to_meme_ratio",
    color="orange",
)
plt.title("Major to MEME Market Capitalization Ratio Over Time")
plt.xlabel("Time")
plt.ylabel("Market Capitalization Ratio")
plt.legend()
plt.grid()
plt.show()
plt.close()

# %%
# 计算 major_1st_mktval 相隔12个时间戳的涨幅
_1st_m2m_returns = _1st_major_to_meme_ratio.pct_change(periods=96)

# 计算 major_rest_mktval 相隔12个时间戳的涨幅
_2st_m2m_returns = _3st_major_to_meme_ratio.pct_change(periods=96)

# 使用涨幅序列作为 lead_lag_correlation 的输入
lead_lag_correlation(_1st_m2m_returns, _2st_m2m_returns, max_lag=24, interval=36)

# %%
# major_1st_mktval
# major_rest_mktval
# meme_1st_mktval
# meme_rest_mktval


# 计算 major_1st_mktval 相隔12个时间戳的涨幅
_1st_m2m_returns = major_1st_mktval.pct_change(periods=96)

# 计算 major_rest_mktval 相隔12个时间戳的涨幅
rest_m2m_returns = major_rest_mktval.pct_change(periods=96)

# 使用涨幅序列作为 lead_lag_correlation 的输入
lead_lag_correlation(_1st_m2m_returns, rest_m2m_returns, max_lag=24, interval=96)
